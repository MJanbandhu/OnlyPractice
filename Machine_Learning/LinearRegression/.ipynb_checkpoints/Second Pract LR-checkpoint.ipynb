# %% [markdown]
# # Problem statement
# Use relevant machine learning model to predict total sales using features
# like money spent on different marketing fields

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as snb
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import/Load Data

# %%
data=pd.read_csv("advertising.csv")

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # Domain Analysis

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# * TV:
# * Radio:
# * Newspaper
# * Sales
# - This data gives an information about total amount spent on
# TV, radio and newspaper advertising and total sales made by
# company based on that investment.

# %% [markdown]
# # Basic Check

# %%
data.shape
# Out:
# (200, 5)

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
num_col=data.select_dtypes(include=["int64","float64"]).columns
num_col
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# perform statistical analysis
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.drop("Unnamed: 0",axis=1, replace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 data.drop("Unnamed: 0",axis=1, replace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'replace'

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
print(data.mean())
print(data.median())
print(data.mode())
# Out:
# TV           147.0425
# Radio         23.2640
# Newspaper     30.5540
# Sales         14.0225
# dtype: float64
# TV           149.75
# Radio         22.90
# Newspaper     25.75
# Sales         12.90
# dtype: float64
#       TV  Radio  Newspaper  Sales
# 0   17.2    4.1        8.7    9.7
# 1   76.4    5.7        9.3    NaN
# 2  109.8    NaN       25.6    NaN
# 3  177.0    NaN        NaN    NaN
# 4  184.9    NaN        NaN    NaN
# 5  197.6    NaN        NaN    NaN
# 6  199.8    NaN        NaN    NaN
# 7  222.4    NaN        NaN    NaN
# 8  237.4    NaN        NaN    NaN
# 9  240.1    NaN        NaN    NaN

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# * Univariate Analysis: dis, Hist, Count and Box
# * Bivariate Analysis: Line,Rel, Scatter, Pie, Bar, Box, Violet and  Swarm
# * Multivarite Analysis: Pair, Heap Map

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(5,3))
snb.histplot(data=data, x='TV' )
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
# check the distribution of Tv
plt.figure(figsize=(3,3))
snb.histplot(data=data,x='TV',kde=True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(3,3))
snb.scatterplot(data=data,x="TV",y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# # Insights
# * There is positive relationship between TV and sales.
# * Sales increases as we increase the amount investing on TV marketing.

# %%
plt.figure(figsize=(3,3))
snb.scatterplot(data=data,x="Radio",y="Sales" ,color='red', hue="Sales") #, ci=None kind=line
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %% [markdown]
# # Multivariate Analysis

# %%
snb.pairplot(data)

# %%
snb.heatmap(data)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Check Outlier

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data=data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(3,3))
snb.boxplot(data=data,x='Newspaper')
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# So Here the outliers

# %% [markdown]
# ## IQR Method to Handle outliers

# %%
data.quantile(0.25)
# Out:
# TV           74.375
# Radio         9.975
# Newspaper    12.750
# Sales        10.375
# Name: 0.25, dtype: float64

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
data.discribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 data.discribe()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'discribe'

# %%
data.nunique()
# Out:
# TV           190
# Radio        167
# Newspaper    172
# Sales        121
# dtype: int64

# %%
data.nunique()
# Out:
# TV           190
# Radio        167
# Newspaper    172
# Sales        121
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# TV           0.0
# Radio        0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %% [markdown]
# # IQR Method to Handle outliers

# %%
data['TV'].quantile(0.25)
# Out:
# 74.375

# %%
data["Newspaper"].quantile(0.25)
# Out:
# 12.75

# %%
# find the Q1 and Q3
Q1=data['Newspaper'].quantile(0.25)
Q3=data['Newspaper'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 32.35

# %%
# finding Upper Limit and Lower Limit
upper_limit=Q1-1.5*IQR
lower_limit=Q3+1.5*IQR

# %%
print(IQR)
print(Q1)
print(Q3)
# Out:
# 32.35
# 12.75
# 45.1

# %%
print(" Lower quartile",Q1)
print("upper quartile",Q3)
print("Inter quartile range",IQR)
print("Lower limit",lower_limit)
print("upper limit",upper_limit)
# Out:
#  Lower quartile 12.75
# upper quartile 45.1
# Inter quartile range 32.35
# Lower limit 93.625
# upper limit -35.775000000000006

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data)
# Out:
# <Axes: >

# %%
IQR
# Out:
# 32.35

# %%
data.loc[data['Newspaper']<lower_limit]
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data=data,x='Newspaper')
# Out:
# <Axes: xlabel='Newspaper'>

# %%
data.loc[data['Newspaper']>upper_limit]
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data=data,x='Newspaper')
# Out:
# <Axes: xlabel='Newspaper'>

# %%
data.loc[data['Newspaper']>upper_limit,'Newspaper']=data['Newspaper'].median()

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8      25.75   22.1
# 1     44.5   39.3      25.75   10.4
# 2     17.2   45.9      25.75    9.3
# 3    151.5   41.3      25.75   18.5
# 4    180.8   10.8      25.75   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7      25.75    7.6
# 196   94.2    4.9      25.75    9.7
# 197  177.0    9.3      25.75   12.8
# 198  283.6   42.0      25.75   25.5
# 199  232.1    8.6      25.75   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data=data,x='Newspaper')
# Out:
# <Axes: xlabel='Newspaper'>

# %%
snb.boxplot(data=data,x='Newspaper')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 snb.boxplot(data=data,x='Newspaper')
#
# NameError: name 'snb' is not defined

# %%
plt.figure(figsize=(5,5))
snb.boxplot(data )
# Out:
# <Axes: >

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8      25.75   22.1
# 1     44.5   39.3      25.75   10.4
# 2     17.2   45.9      25.75    9.3
# 3    151.5   41.3      25.75   18.5
# 4    180.8   10.8      25.75   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7      25.75    7.6
# 196   94.2    4.9      25.75    9.7
# 197  177.0    9.3      25.75   12.8
# 198  283.6   42.0      25.75   25.5
# 199  232.1    8.6      25.75   13.4
#
# [200 rows x 4 columns]

# %%
# import minmax scaler
from sklearn.preprocessing import MinMaxScaler
# initialise minmaxscaler
scaling=MinMaxScaler()
data[['TV','Radio','Newspaper']]=scaling.fit_transform(data[['TV','Radio','Newspaper']])

# %%
 data
# Out:
#            TV     Radio  Newspaper  Sales
# 0    0.775786  0.762097        0.0   22.1
# 1    0.148123  0.792339        0.0   10.4
# 2    0.055800  0.925403        0.0    9.3
# 3    0.509976  0.832661        0.0   18.5
# 4    0.609063  0.217742        0.0   12.9
# ..        ...       ...        ...    ...
# 195  0.126818  0.074597        0.0    7.6
# 196  0.316199  0.098790        0.0    9.7
# 197  0.596212  0.187500        0.0   12.8
# 198  0.956713  0.846774        0.0   25.5
# 199  0.782550  0.173387        0.0   13.4
#
# [200 rows x 4 columns]

# %%
data.to_csv("ClenedData",index=False)

# %%
dataa=pd.read_csv("ClenedData")

# %%
dataa
# Out:
#            TV     Radio  Newspaper  Sales
# 0    0.775786  0.762097        0.0   22.1
# 1    0.148123  0.792339        0.0   10.4
# 2    0.055800  0.925403        0.0    9.3
# 3    0.509976  0.832661        0.0   18.5
# 4    0.609063  0.217742        0.0   12.9
# ..        ...       ...        ...    ...
# 195  0.126818  0.074597        0.0    7.6
# 196  0.316199  0.098790        0.0    9.7
# 197  0.596212  0.187500        0.0   12.8
# 198  0.956713  0.846774        0.0   25.5
# 199  0.782550  0.173387        0.0   13.4
#
# [200 rows x 4 columns]

# %%
data.to_csv("CleanedData.csv", index=False)

# %%
data3=pd.read_csv("CleanedData.csv")

# %%
data3
# Out:
#            TV     Radio  Newspaper  Sales
# 0    0.775786  0.762097        0.0   22.1
# 1    0.148123  0.792339        0.0   10.4
# 2    0.055800  0.925403        0.0    9.3
# 3    0.509976  0.832661        0.0   18.5
# 4    0.609063  0.217742        0.0   12.9
# ..        ...       ...        ...    ...
# 195  0.126818  0.074597        0.0    7.6
# 196  0.316199  0.098790        0.0    9.7
# 197  0.596212  0.187500        0.0   12.8
# 198  0.956713  0.846774        0.0   25.5
# 199  0.782550  0.173387        0.0   13.4
#
# [200 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as snb
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data2=pd.read_csv("CleanedData.csv")

# %%
data2
# Out:
#            TV     Radio  Newspaper  Sales
# 0    0.775786  0.762097        0.0   22.1
# 1    0.148123  0.792339        0.0   10.4
# 2    0.055800  0.925403        0.0    9.3
# 3    0.509976  0.832661        0.0   18.5
# 4    0.609063  0.217742        0.0   12.9
# ..        ...       ...        ...    ...
# 195  0.126818  0.074597        0.0    7.6
# 196  0.316199  0.098790        0.0    9.7
# 197  0.596212  0.187500        0.0   12.8
# 198  0.956713  0.846774        0.0   25.5
# 199  0.782550  0.173387        0.0   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(3,3))
snb.boxplot(data=data2, x="Newspaper")
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# # Feture Engineering

# %%
data=data2

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809        NaN  0.782224
# Radio      0.054809  1.000000        NaN  0.576223
# Newspaper       NaN       NaN        NaN       NaN
# Sales      0.782224  0.576223        NaN  1.000000

# %%
snb.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
# creating X and Y variable

# %%
x=data.drop("Sales",axis=1)
y=data[["Sales"]]

# %%
x
# Out:
#            TV     Radio  Newspaper
# 0    0.775786  0.762097        0.0
# 1    0.148123  0.792339        0.0
# 2    0.055800  0.925403        0.0
# 3    0.509976  0.832661        0.0
# 4    0.609063  0.217742        0.0
# ..        ...       ...        ...
# 195  0.126818  0.074597        0.0
# 196  0.316199  0.098790        0.0
# 197  0.596212  0.187500        0.0
# 198  0.956713  0.846774        0.0
# 199  0.782550  0.173387        0.0
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
x=data.drop("Sales",axis=1)
y=data[["Sales"]]

# %%
print(x)
print(f"{y}")
# Out:
#            TV     Radio  Newspaper
# 0    0.775786  0.762097        0.0
# 1    0.148123  0.792339        0.0
# 2    0.055800  0.925403        0.0
# 3    0.509976  0.832661        0.0
# 4    0.609063  0.217742        0.0
# ..        ...       ...        ...
# 195  0.126818  0.074597        0.0
# 196  0.316199  0.098790        0.0
# 197  0.596212  0.187500        0.0
# 198  0.956713  0.846774        0.0
# 199  0.782550  0.173387        0.0
#
# [200 rows x 3 columns]
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
# spliting data for traing and testing
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test= train_test_split(x,y, test_size=0.30, random_state=4)

# %%
x_test.size
# Out:
# 180

# %%
x_train.shape
# Out:
# (140, 3)

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Apply Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[17.25874785],
#        [16.82980841],
#        [22.01483249],
#        [24.57117689],
#        [12.27234854],
#        [21.00756667],
#        [10.16284416],
#        [12.31785147],
#        [11.77975231],
#        [17.03160318],
#        [22.74529685],
#        [15.27730653],
#        [ 8.55075653],
#        [15.00106998],
#        [18.55099263],
#        [18.68314404],
#        [18.85362286],
#        [14.41731955],
#        [ 9.79138477],
#        [20.62521576],
#        [14.81727913],
#        [17.73513185],
#        [23.05639809],
#        [ 7.77699909],
#        [21.55588989],
#        [19.42635713],
#        [13.93642825],
#        [11.69327188],
#        [18.37911658],
#        [12.36903173],
#        [11.45456824],
#        [10.01074719],
#        [13.51439372],
#        [15.18752985],
#        [18.11164214],
#        [ 6.93543498],
#        [14.06188223],
#        [14.29568411],
#        [14.08255836],
#        [10.74102378],
#        [14.94734535],
# ...

# %%
actual_value=y_test.copy()

# %%
actual_value['Pred']=y_pred

# %%
actual_value
# Out:
#      Sales       Pred
# 11    17.4  17.258748
# 99    17.2  16.829808
# 128   24.7  22.014832
# 175   27.0  24.571177
# 1     10.4  12.272349
# 111   21.8  21.007567
# 90    11.2  10.162844
# 177   11.7  12.317851
# 88    12.9  11.779752
# 187   17.3  17.031603
# 61    24.2  22.745297
# 199   13.4  15.277307
# 191    9.9   8.550757
# 123   15.2  15.001070
# 184   17.6  18.550993
# 188   15.9  18.683144
# 33    17.4  18.853623
# 171   14.5  14.417320
# 138    9.6   9.791385
# 84    21.7  20.625216
# 81    12.3  14.817279
# 102   14.8  17.735132
# 147   25.4  23.056398
# 34     9.5   7.776999
# 47    23.2  21.555890
# 124   19.7  19.426357
# 112   14.1  13.936428
# 6     11.8  11.693272
# 14    19.0  18.379117
# 190   10.8  12.369032
# 80    11.8  11.454568
# 18    11.3  10.010747
# 167   12.2  13.514394
# 45    14.9  15.187530
# 153   19.0  18.111642
# 119    6.6   6.935435
# 100   11.7  14.061882
# 83    13.6  14.295684
# 181   12.2  14.082558
# 71    12.4  10.741024
# ...

# %%
y_test
# Out:
#      Sales
# 11    17.4
# 99    17.2
# 128   24.7
# 175   27.0
# 1     10.4
# 111   21.8
# 90    11.2
# 177   11.7
# 88    12.9
# 187   17.3
# 61    24.2
# 199   13.4
# 191    9.9
# 123   15.2
# 184   17.6
# 188   15.9
# 33    17.4
# 171   14.5
# 138    9.6
# 84    21.7
# 81    12.3
# 102   14.8
# 147   25.4
# 34     9.5
# 47    23.2
# 124   19.7
# 112   14.1
# 6     11.8
# 14    19.0
# 190   10.8
# 80    11.8
# 18    11.3
# 167   12.2
# 45    14.9
# 153   19.0
# 119    6.6
# 100   11.7
# 83    13.6
# 181   12.2
# 71    12.4
# 26    15.0
# 134   10.8
# 180   10.5
# 158    7.3
# 189    6.7
# 89    16.7
# 48    14.8
# 116   12.2
# 12     9.2
# 69    22.3
# 110   13.4
# 154   15.6
# 16    12.5
# 19    14.6
# 2      9.3
# 143   10.4
# 185   22.6
# 29    10.5
# 155    3.2
# 24     9.7

# %% [markdown]
# # Model Evoluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# mean Ansolute Error
# actual value - predicted value
MAE=mean_absolute_error(y_test,y_pred)

# %%
MAE
# Out:
# 1.178074781293774

# %%
# Mean squared error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 2.1354065944216365

# %%
# RMSE
RMSE= np.sqrt(MSE)

# %%
RMSE
# Out:
# 1.4613030467434318

# %%
r2_s =r2_score(y_test,y_pred)

# %%
r2_s
# Out:
# 0.916190312067672

# %% [markdown]
# # Double

# %% [markdown]
# spliting data into x and y variable

# %%
import pandas as pd
data= pd.read_csv('Cleaneddata.csv')

# %%
data.head(2)
# Out:
#          TV     Radio  Newspaper  Sales
# 0  0.775786  0.762097        0.0   22.1
# 1  0.148123  0.792339        0.0   10.4

# %%
x=data.drop("Sales", axis=1)
y=data[['Sales']]

# %%
print(x.head(2))
print(y.head(2))
# Out:
#          TV     Radio  Newspaper
# 0  0.775786  0.762097        0.0
# 1  0.148123  0.792339        0.0
#    Sales
# 0   22.1
# 1   10.4

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# %% [markdown]
# # __________________

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)

# %%
y_pred
# Out:
# array([[17.25874785],
#        [16.82980841],
#        [22.01483249],
#        [24.57117689],
#        [12.27234854],
#        [21.00756667],
#        [10.16284416],
#        [12.31785147],
#        [11.77975231],
#        [17.03160318],
#        [22.74529685],
#        [15.27730653],
#        [ 8.55075653],
#        [15.00106998],
#        [18.55099263],
#        [18.68314404],
#        [18.85362286],
#        [14.41731955],
#        [ 9.79138477],
#        [20.62521576],
#        [14.81727913],
#        [17.73513185],
#        [23.05639809],
#        [ 7.77699909],
#        [21.55588989],
#        [19.42635713],
#        [13.93642825],
#        [11.69327188],
#        [18.37911658],
#        [12.36903173],
#        [11.45456824],
#        [10.01074719],
#        [13.51439372],
#        [15.18752985],
#        [18.11164214],
#        [ 6.93543498],
#        [14.06188223],
#        [14.29568411],
#        [14.08255836],
#        [10.74102378],
#        [14.94734535],
# ...

# %%
actual_value = y_test.copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 actual_value = y_test.copy() and y_pred.copy()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
actual_value['Predicted_Value']=y_pred
actual_value
# Out:
#      Sales  Predicted_Value
# 11    17.4        17.258748
# 99    17.2        16.829808
# 128   24.7        22.014832
# 175   27.0        24.571177
# 1     10.4        12.272349
# 111   21.8        21.007567
# 90    11.2        10.162844
# 177   11.7        12.317851
# 88    12.9        11.779752
# 187   17.3        17.031603
# 61    24.2        22.745297
# 199   13.4        15.277307
# 191    9.9         8.550757
# 123   15.2        15.001070
# 184   17.6        18.550993
# 188   15.9        18.683144
# 33    17.4        18.853623
# 171   14.5        14.417320
# 138    9.6         9.791385
# 84    21.7        20.625216
# 81    12.3        14.817279
# 102   14.8        17.735132
# 147   25.4        23.056398
# 34     9.5         7.776999
# 47    23.2        21.555890
# 124   19.7        19.426357
# 112   14.1        13.936428
# 6     11.8        11.693272
# 14    19.0        18.379117
# 190   10.8        12.369032
# 80    11.8        11.454568
# 18    11.3        10.010747
# ...

# %% [markdown]
# # Model EValuation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
MAE= mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1.178074781293774

# %%
MSE= mean_squared_error(y_test,y_pred)
MSE
# Out:
# 2.1354065944216365

# %% [markdown]
# # RMSE= np.sqrt(MSE)

# %%
import numpy as np

# %%
RMSE= np.sqrt(MSE)
RMSE
# Out:
# 1.4613030467434318

# %% [raw]
# R2_Sco= r2_score(y_test,y_pred)

# %%
R2_Sco= r2_score(y_test,y_pred)
R2_Sco
# Out:
# 0.916190312067672

# %% [markdown]
# # AdjR2Score

# %%
adjr2score=
