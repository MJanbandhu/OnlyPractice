# %% [markdown]
# # Sigmoid Function
#
#
# is mathematical function / Activation function(Which is use in DL) that we use to transform continues value into a probability value which lies within a range o to 1
