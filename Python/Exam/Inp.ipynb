# %%
inp_list= list(map(int, input("Enter Number").split()))
# Out:
# Enter Number4  8 7 8  8  8  8

# %%
.split()# User enters numbers separated by space
inp = list(map(int, input("Enter numbers separated by space: ").split()))
print(inp)
