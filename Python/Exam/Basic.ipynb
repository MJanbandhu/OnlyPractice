# %%
print("Mohit Janbandhu")
# Out:
# Mohit Janbandhu

# %%
# Arithmatic Operaters

# %%
# Logical Operaters

# %%
'''
Arithmetic Operater 
relational/ Comparision Operators
Logical Operaters
Assignment Operaters
BitWise Operater
'''

# %%
import da
