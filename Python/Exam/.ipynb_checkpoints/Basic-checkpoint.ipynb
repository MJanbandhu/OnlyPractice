# %%
print("Mohit Janbandhu")
# Out:
# Mohit Janbandhu

# %%
# Arithmatic Operaters

# %%
# Logical Operaters

# %%
'''
Arithmetic Operater 
relational/ Comparision Operators
Logical Operaters
Assignment Operaters
BitWise Operater
'''

# %%
import datetime

# %%
curr_dt=datetime.datetime.now()

# %%
curr_dt
# Out:
# datetime.datetime(2025, 12, 30, 0, 47, 12, 459396)

# %%
curr_day= datetime.datetime.today()
curr_day
# Out:
# datetime.datetime(2025, 12, 30, 0, 57, 9, 806770)

# %%
curr_tm= datetime.datetime.time()
curr_tm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 curr_tm= datetime.datetime.time()
#       2 curr_tm
#
# TypeError: unbound method datetime.time() needs an argument

# %%
from datetime import datetime, date, timedelta

# Access classes directly by name
current_datetime = datetime.now()
today_date = date.today()

# %%
 
current_datetime
# Out:
# datetime.datetime(2025, 12, 30, 0, 58, 4, 694261)

# %%
today_date
# Out:
# datetime.date(2025, 12, 30)

# %%
from datetime import datetime

now = datetime.now()
# Format as "Month Day, Year Hour:Minute AM/PM"
formatted_string = now.strftime("%B %d, %Y %I:%M %p")
print(formatted_string)
# Out:
# December 30, 2025 12:59 AM

# %%
now
# Out:
# datetime.datetime(2025, 12, 30, 0, 59, 6, 43977)
