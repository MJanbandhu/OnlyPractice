# %% [markdown]
# # Basics

# %% [markdown]
# Importing Keyword and showing KeyWords

# %%
import keyword

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Imorting sys (SystemOS)

# %%
import sys

# %% [markdown]
# # Variables

# %%
# integer
intvar = 1000
print(intvar)
print(type(intvar))
print(sys.getsizeof(intvar))
print(isinstance(intvar,int))
print(isinstance(intvar,float))
# Out:
# 1000
# <class 'int'>
# 28
# True
# False

# %%
# Float
floatvar = 10.23234242423423
print(floatvar)
print(type(floatvar))
print(sys.getsizeof(floatvar))
print(isinstance(floatvar,float))
# Out:
# 10.23234242423423
# <class 'float'>
# 24
# True

# %%
# Boolean

bool1 = True
bool2 = False
print(type(bool1))
print(isinstance(bool1,bool))
print(isinstance(bool1,int))
print(isinstance(bool2,bool))
print(isinstance(bool2,int))
# Out:
# <class 'bool'>
# True
# True
# True
# True

# %%
print(bool("apple"))
print(bool("banana"))
print(bool(34))
print(bool(45.35))
print(bool(0))
print(bool(""))
print(bool('adasadsafwsdfabjhsdbjasfb'))
# Out:
# True
# True
# True
# True
# False
# False
# True

# %%
## string

strvar = "apple"
print(strvar)
print(type(strvar))
print(sys.getsizeof(strvar))
print(isinstance(strvar,str))
# Out:
# apple
# <class 'str'>
# 54
# True

# %%
## String indexing
myvar = "Hello World"
# fetch 'W' from myvar
print(myvar[6])
print(myvar[-5])
# fetch 'r' from myvar
print(myvar[8])
print(myvar[-3])
# fetch the last character of myvar
print(myvar[-1])
# Out:
# W
# W
# r
# r
# d

# %%
print(myvar)
print(len(myvar))
print(myvar.count('l'))
print(myvar.startswith("He"))
print(myvar.startswith("Hell"))
print(myvar.startswith("err"))
print(myvar.endswith("ld"))
print(myvar.index("e"))
print(myvar.index('l'))
# Out:
# Hello World
# 11
# 3
# True
# True
# False
# True
# 1
# 2

# %% [markdown]
# # ---------------------

# %%
str1="Mohit Janbandhu"

# %%
str1
# Out:
# 'Mohit Janbandhu'

# %%
len(str1)
# Out:
# 15

# %%
str1.startswith('O')
# Out:
# False

# %%
str1.endswith('u')
# Out:
# True

# %%
str1.index('i')
# Out:
# 3

# %%
str1[1]
# Out:
# 'o'

# %%
str1.[1:6:]
# Out:
#   Cell In[21], line 1
#     str1.[1:6:]
#          ^
# SyntaxError: invalid syntax

# %%
str1[:-6:]
# Out:
# 'Mohit Jan'

# %%
str1[::-1]
# Out:
# 'uhdnabnaJ tihoM'

# %%
str1[:2:-1]
# Out:
# 'uhdnabnaJ ti'

# %%
str1[1:8:1]
# Out:
# 'ohit Ja'

# %%
str1[1:12:2]
# Out:
# 'oi abn'

# %%
## Immutability
str1[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 ## Immutability
# ----> 2 str1[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
str1.replace('A','a')
# Out:
# 'Mohit Janbandhu'

# %%
str1.replace('a','A')
# Out:
# 'Mohit JAnbAndhu'

# %%
mysen = "Natural language processing with Python"
print(mysen.partition("language"))
# Out:
# ('Natural ', 'language', ' processing with Python')

# %%
str1.partition("Mohit")
# Out:
# ('', 'Mohit', ' Janbandhu')

# %%
str1
# Out:
# 'Mohit Janbandhu'

# %%
myword = "**************Hello world*****************"
myword1 = myword.strip("*")
print(myword)
print(myword1)
# Out:
# **************Hello world*****************
# Hello world

# %%
str1.split()
# Out:
# ['Mohit', 'Janbandhu']

# %%
str1
# Out:
# 'Mohit Janbandhu'

# %%
price_banana = 100
price_apple = 250

# .format method
print("The price of apple is {} and price of banana is {}".format(price_apple,price_banana))

# f string literals

print(f"The price of apple is {price_apple} and price of banana is {price_banana}")

print("The price of apple is",price_apple,"and price of banana is",price_banana)
# Out:
# The price of apple is 250 and price of banana is 100
# The price of apple is 250 and price of banana is 100
# The price of apple is 250 and price of banana is 100

# %%
print("This is my name {}".format(str1))
# Out:
# This is my name Mohit Janbandhu

# %%
print(f"this is my name {str1}")
# Out:
# this is my name Mohit Janbandhu

# %%
print("This is my name ",str1)
# Out:
# This is my name  Mohit Janbandhu

# %%
print("My name is ",str1)
# Out:
# My name is  Mohit Janbandhu

# %% [markdown]
# # Typecasting

# %%
## Typecasting --> It is a process of converting dissimilar datatypes to a similar datatype
##                 so that the operation can happen.
# Auto typecasting --> Automatically changing datatypes
print(5.0 + 2)

# 5.0 --> float --> 5.0
# 2 ---> integer --> float --> 2.0
# 5.0 + 2.0 = 7.0

print(2 + True)
# 2 --> integer -->2
# True --> bool --> int --> 1
# 2 + 1 = 3

print("3" + 3)
# Out:
# 7.0
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 15
#      10 print(2 + True)
#      11 # 2 --> integer -->2
#      12 # True --> bool --> int --> 1
#      13 # 2 + 1 = 3
# ---> 15 print("3" + 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
## Forced Typecasting --> Manual changing the datatype
## int --> integer
## float
## str --> string
## bool -- Boolean

a = 5
print(type(a))
b = float(a)
print(type(b))
print(a)
print(b)
print("=================")
c = 78
print(type(c))
d = str(c)
print(type(d))
print(c)
print(d)
# Out:
# <class 'int'>
# <class 'float'>
# 5
# 5.0
# =================
# <class 'int'>
# <class 'str'>
# 78
# 78

# %%
## Arithmatic operators
a = 5
b = 2

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print("floor division of a by b = {}".format(a//b))
print("a modulus b = {}".format(a%b))
print("5 raise to power 2 is {}".format(5**2))
print("5 raise to power 3 is {}".format(5**3))
# Out:
# 7
# 3
# 10
# 2.5
# floor division of a by b = 2
# a modulus b = 1
# 5 raise to power 2 is 25
# 5 raise to power 3 is 125

# %%
#Assignment Operators
# /= Like that

# %%
#  Comparison (Relational) Conditional Operator
a = 5
b = 2

print(a>b)
print(a<b)
print(a == b)
print(a>=b)
print(a<=b)
print(a != b)
# Out:
# True
# False
# False
# True
# False
# True

# %%
#Logistic Operator

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
print("==============")
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# False
# False
# False
# ==============
# True
# True
# True
# False

# %%
print(True not True)
print(True not False)
print(False not True)
# Out:
#   Cell In[67], line 1
#     print(True not True)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(True is not True)
print(True is not False)
print(False is not True)
# Out:
# False
# True
# True

# %% [markdown]
# # ------

# %% [markdown]
# # Data Structure

# %% [markdown]
# # List

# %% [markdown]
# # Set

# %% [markdown]
# # Dict

# %% [markdown]
# # Comparision

# %%
# List
    * append
    * insert
    * Extend
    * pop
    * remove
    
    * Clear
    * del


# Set
     * add
     * update
    
     * remove
     * discard
    
     * Clear
     * del

# %% [markdown]
# ## List
#
#         append
#
#         insert
#
#         extend
#
#         pop
#
#         remove
#
#     clear
#
#     del
#
#     sort
#
#     reverse
#
#     count
#
#     index
#
#     copy
#
# ## Tuple
#
#         (Tuple is immutable, so fewer operations)
#
#         count
#
#         index
#
#         Can convert to list for modification
#
# ## Set
#
#         add
#
#         update
#
#         remove
#
#         discard
#
#         pop
#
#     clear
#
#     del
#
#     union
#
#     intersection
#
#     difference
#
#     symmetric_difference
#
#     copy
#
# ## Dictionary
#
#     get
#
#     keys
#
#     values
#
#         items
#
#         update
#
#         pop
#
#         popitem
#
#     clear
#
#     del
#
#     copy
#
#     setdefault
