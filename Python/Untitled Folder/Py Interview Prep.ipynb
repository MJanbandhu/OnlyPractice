# %%
numb= list(('mohit', 'ashok','janbandhu'))

# %%
numb.

# %%
type(numb)
# Out:
# list

# %%
x=[1,2,3]
y=[1,2,3]

# %%
x is y
# Out:
# False

# %%
id.x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 id.x
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'x'

# %%
implecit typecasting and diplicit type casting

# %%
How Diff python with other prog language?
1 intentation

# %% [markdown]
# # check if Bank Balance is enough befor withdrawing

# %%
check_amt= int(input("Enter amount"))
amount=50000
if check_amt<= amount:
    print(" You can withdraw")
    
else:
    print(" Amount isn't enough")
# Out:
# Enter amount20000
#  You can withdraw

# %% [markdown]
# # diff bet print and return

# %%
def addition (a,b):
    print(a+b)
ref=addition(4,5)

print(ref)
# Out:
# 9
# None

# %%
def addition (a,b):
    return (a+b)
ref=addition(4,5)

print(ref)
# Out:
# 9

# %% [markdown]
# # Function Type

# %% [markdown]
# # User define fun
#
# we use def

# %% [markdown]
# # types of argument

# %%
def addition (a,b):# parameter
    return (a+b) 
ref=addition(4,5) # argument

print(ref)

# %% [markdown]
# #### argument type
# #### four type of argument
#     1 required or positional agr
#     2 defalt arg
#     3 keyword agr
#     4 variable length arg *

# %% [markdown]
# # OOPs
