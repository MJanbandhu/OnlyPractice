# %%
list1=[6,9,8,5,8,5,2,8,(8,8,9,6,5,4,7,2)]

# %%
list1[8][3]
# Out:
# 6

# %%
list1[8]
# Out:
# (8, 8, 9, 6, 5, 4, 7, 2)

# %%
mohit= "Mohit Janbandhu 1234"

# %%
vowels= "AEIOUaeiou"

# %%
countofappear=[ ]
for char in mohit:
    if char in vowels:
        print(char)
        
        countofappear.append(char)
# Out:
# o
# i
# a
# a
# u

# %%
len(countofappear)
# Out:
# 5

# %%
mohit = "mohit janbandhu 1234"
vowels = "aeiou"

countofappear = {}

for char in mohit:
    if char in vowels:
        print(char)
        countofappear[char] = countofappear.get(char, 0) + 1

print(countofappear)
# Out:
# o
# i
# a
# a
# u
# {'o': 1, 'i': 1, 'a': 2, 'u': 1}

# %%
list1
# Out:
# [6, 9, 8, 5, 8, 5, 2, 8, (8, 8, 9, 6, 5, 4, 7, 2)]

# %%
for i in list1:
    if i % 2 ==0:
        print("Even")
        
    else:
        ("Odd")
# Out:
# Even
# Even
# Even
# Even
# Even
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in list1:
# ----> 2     if i % 2 ==0:
#       3         print("Even")
#       5     else:
#
# TypeError: unsupported operand type(s) for %: 'tuple' and 'int'

# %% [markdown]
# # Lambda function

# %%
list1=[6,9,8,5,8,5,2,8,1,2,3,4,6,7]

# %%
lam_fun= map (lambda ev_odd : "Even" if ev_odd %2==0 else "odd", list1)

# %%
print(list(lam_fun))
# Out:
# ['Even', 'odd', 'Even', 'odd', 'Even', 'odd', 'Even', 'Even', 'odd', 'Even', 'odd', 'Even', 'Even', 'odd']

# %%
lam_fun

# %% [markdown]
# # Function

# %%
def check_even_odd (num):
    if num %2==0:
        print("Even")
        
    else:
        print("Odd")
check_even_odd(list1)

# %%
check_even_odd(list1)
# Out:
# Odd

# %%
 for i in list1:
        check_even_odd(i)
# Out:
# Even
# Odd
# Even
# Odd
# Even
# Odd
# Even
# Even
# Odd
# Even
# Odd
# Even
# Even
# Odd

# %%
numbers = [0, 1, 2, 3, 10, 15, 22, 33, 100]

for number in numbers:
    print(f"{number} is {check_even_odd(number)}")
# Out:
# Even
# 0 is None
# Odd
# 1 is None
# Even
# 2 is None
# Odd
# 3 is None
# Even
# 10 is None
# Odd
# 15 is None
# Even
# 22 is None
# Odd
# 33 is None
# Even
# 100 is None

# %%
# input

# %%
mj= int(input("Enter a number"))

def ev_odd(mj):
    if mj %2==0:
        print("Even")
        
    else:
        print("Odd")
        
        
ev_odd(mj)
# Out:
# Enter a number5
# Odd

# %% [markdown]
# # ---------------------------------

# %%
fruits = ["apple", "banana", "cherry"]

# %%
for fruit in fruits:
    if fruit =='banana':
        print(fruit)
# Out:
# banana

# %%
for fruit in fruits:
    if "ban" in fruit:
        print(fruit)
# Out:
# banana

# %%
print([fruit for fruit in fruits if "ban" in fruit])
# Out:
# ['banana']

# %%
mohit
# Out:
# 'Mohit Janbandhu 1234'

# %%
vowels ="AEIOUaeiou"
for char in mohit:
    if char in vowels:
        print(char)
# Out:
# o
# i
# a
# a
# u

# %%
upper_case= 0
lower_case=0
digits=0

upper_letter=[]
lower_letter=[]
digits_all=[]

# %%
for char in mohit:
    if char.isupper():
        upper_case +=1
        upper_letter.append(char)
        
        
    elif char.islower():
        lower_case +=1
        lower_letter.append(char)
        
        
        
    elif char.isdigit():
        digits +=1
        digits_all.append(char)

# %%
upper_letter
# Out:
# ['M', 'J']

# %%
print("Upper case letter count is", upper_case)
print("Lower case letter count is{}".format(lower_case))
print(f"digit count is {digits}")
# Out:
# Upper case letter count is 2
# Lower case letter count is12
# digit count is 4

# %%
print("Upper case letter are ", upper_letter)
print("Lower case letter are {}".format(lower_letter))
print(f"Digits are {digits_all}")
# Out:
# Upper case letter are  ['M', 'J']
# Lower case letter are ['o', 'h', 'i', 't', 'a', 'n', 'b', 'a', 'n', 'd', 'h', 'u']
# Digits are ['1', '2', '3', '4']
