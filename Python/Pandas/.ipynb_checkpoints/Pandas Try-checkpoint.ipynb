# %% [markdown]
# - pandas -- Panel Data
# - Any data used for research or study purposes
# - Objects --> 1 .Series -- 1 Column Multiple rows
#               2. Data Frame -- multiple rows and columns
# - Built on numpy

# %%
import pandas as pd

# %%
## Creating empty series
d=pd.Series()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14364\779336895.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   d=pd.Series()

# %%
d
# Out:
# Series([], dtype: float64)

# %%
e=pd.DataFrame()

# %%
print(type(e))
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
## Creating series with one element
d=pd.Series(17)

# %%
d
# Out:
# 0    17
# dtype: int64

# %%
## Creating series using tuple
t=(10,11,12)
d=pd.Series(t)
d
# Out:
# 0    10
# 1    11
# 2    12
# dtype: int64
