# %% [markdown]
# #

# %%
import seaborn as snb

# %%
data=snb.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Infercial Statestics

# %% [markdown]
# # Cetral Tendency

# %% [markdown]
# * Mean
#     * Median
#         * mode

# %%
data['sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
data.mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17028\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
data['petal_length'].mode()
# Out:
# 0    1.4
# 1    1.5
# Name: petal_length, dtype: float64

# %%
data['sepal_length'].median()
# Out:
# 5.8

# %%
data.skew()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17028\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64

# %%
data['sepal_length'].skew()
# Out:
# 0.3149109566369728

# %%
data.kurt()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17028\2907027414.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurt()
# sepal_length   -0.552064
# sepal_width     0.228249
# petal_length   -1.402103
# petal_width    -1.340604
# dtype: float64

# %%
data['sepal_length'].kurt()
# Out:
# -0.5520640413156395

# %%
data.cov()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17028\4020818503.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.cov()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
data.corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17028\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# range
minn=data['sepal_length'].min()
maxx = data['sepal_length'].max()

rangee=maxx-minn
rangee
# Out:
# 3.6000000000000005

# %%
# range
range=data["sepal_length"].max()-data["sepal_length"].min()
print(range)
# Out:
# 3.6000000000000005

# %%
# varience
data['sepal_length'].var()
# Out:
# 0.6856935123042505

# %%
data['sepal_length'].cov()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 data['sepal_length'].cov()
#
# TypeError: Series.cov() missing 1 required positional argument: 'other'

# %%
data['sepal_length'].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 data['sepal_length'].corr()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'

# %%
data['sepal_length'].std()
# Out:
# 0.8280661279778629

# %%
# skwness
data['sepal_length'].skew()
# Out:
# 0.3149109566369728

# %%
# kurtosis
data['sepal_length'].kurt()
# Out:
# -0.5520640413156395

# %%
q1=data['sepal_length'].quantile(0.25)
q2=data['sepal_length'].quantile(0.50)
q3=data['sepal_length'].quantile(0.75)

# %%
# IQR
IQR=q3-q1
IQR
# Out:
# 1.3000000000000007

# %%
# covarience
data.cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
# Corelation
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
#    * Parametric Test
#    * Non-Parametric Test

# %% [markdown]
# #### Parametric tests
# 1. Z test
# 2. T/Student’s T test
# 3. Paired t Test
# 4. One Way ANOva

# %% [markdown]
# #### Non parametric tests
# 1. Chi Square Test
# 2. Mann-Whitney Test
# 3. Wilcoxon Signed-Rank Test
# 4. Kruskal-Wallis Test
# 5. Friedman’s ANOVA

# %% [markdown]
# # z test

# %%
# z test
data=[45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42]

# %%
from statsmodels.stats.weightstats import ztest

# %%
from statsmodels.stats.weightstats import ztest
z,p= ztest(data, value=41)

# %%
print(z,p)
# Out:
# 0.45149324894859366 0.6516340896346235

# %% [markdown]
# # T-Test

# %%
data=[14,14,16,13,12,17,15,14,15,13,15,14]

# %%
data1=[45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42]
Total=sum(data1)

# %%
nu= len(data1)

# %%
avg=Total/nu

# %%
avg
# Out:
# 41.333333333333336

# %%
from scipy import stats

# %%
t,p= stats.ttest_1samp(data,15)

# %%
print(t,p)
# Out:
# -1.6848470783484626 0.12014460742498101

# %% [markdown]
# # Paired Test

# %%
pre_test=[88,82,93,75,72,81,67,91,83,79,80,90,91]

post_test=[91,84,88,90,87,92,95,78,89,84,93,94,98]

t,p = stats.ttest_rel(pre_test,post_test)

print("t=",t,"p=",p)
# Out:
# t= -2.503112816173455 p= 0.027756426983475475

# %% [markdown]
# # Anova test

# %%
g1=[85,86,88,75,78,94,98,79,71,80]
g2=[91,92,65,74,72,69,80,81,56,86]
g3=[91,92,65,74,72,69,80,81,56,86]

# %%
from statsmodels.stats.weightstats import ztest

# %%
from scipy import stats

# %%
from scipy.stats import f_oneway

# %%
annova,p= f_oneway(g1,g2,g3)

# %%
print(annova, p)
# Out:
# 1.361245584194688 0.273376088920739

# %% [markdown]
# # ______________________________________________________

# %% [markdown]
# ---------------------

# %% [markdown]
# # Hypothesis Testing

# %%
# Z Test
# z test Campaire sample mean to the population mean
data=[45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42]

# %%
from statsmodels.stats.weightstats import ztest

# %%
z,p= ztest(data, value=35)
print(z,p)
# Out:
# 8.578371730023221 9.62255415335246e-18

# %% [markdown]
# Here we accept the alternative hypothesis

# %%
# T test
data=[14,14,16,13,12,17,15,14,15,13,15,14]
from scipy import stats
t,p= stats.ttest_1samp(data,15)
print(t,p)
# Out:
# -1.6848470783484626 0.12014460742498101

# %%
data=[14,14,16,13,12,17,15,14,15,13,15,14]
from scipy import stats
t,p=stats.ttest_1samp(data,15)

# %%
print(t,p)
# Out:
# -1.6848470783484626 0.12014460742498101

# %%
data=[45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42]

# %%
pre_test=[88,82,93,75,72,81,67,91,83,79,80,90,91]

post_test=[91,84,88,90,87,92,95,78,89,84,93,94,98]

# %%
from scipy import stats
t,p= stats.ttest_rel(pre_test,post_test)
print(t,p)
# Out:
# -2.503112816173455 0.027756426983475475

# %% [markdown]
# # Anova Test

# %%
g1=[85,86,88,75,78,94,98,79,71,80]
g2=[91,92,65,74,72,69,80,81,56,86]
g3=[91,92,65,74,72,69,80,81,56,86]

# %%
from scipy.stats import f_oneway

# %%
anova,p= f_oneway(g1,g2,g3)
print(anova,p)
# Out:
# 1.361245584194688 0.273376088920739

# %% [markdown]
# # Z test
# Sample mean to the population mean

# %% [markdown]
# # T test
# campare data distribution to the hypothaesd (Sample) mean

# %% [markdown]
# # Annova Test
# it campare Three or more independence or feature

# %% [markdown]
# # Chi-Square
# it is used to categorical feature in dataset
#
# there is a relationship between two categorical variables
