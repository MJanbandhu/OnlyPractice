# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# # Z test

# %% [markdown]
# ##### There is a claim that average age of IT male professionals in Bangalore is 35 years.
# 1. H0: Average age is 35 years
# 2. Ha= age is not 35 years

# %%
# z test
data=[45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42,
     45,40,40,45,50,29,40,41,42,45,40,40,45,50,29,40,41,42]

# %%
from statsmodels.stats.weightstats import ztest

# %%
import pandas as pd
import seaborn as sbn
data1= sbn.load_dataset('Iris')

# %%
from statsmodels.stats.weightstats import ztest

# %%
data1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
z,p= ztest(data1['petal_length'],value=4)

# %%
print(z,p)
# Out:
# -1.67896989467615 0.09315791118195946

# %%
print(data)
# Out:
# [45, 40, 40, 45, 50, 29, 40, 41, 42, 45, 40, 40, 45, 50, 29, 40, 41, 42, 45, 40, 40, 45, 50, 29, 40, 41, 42, 45, 40, 40, 45, 50, 29, 40, 41, 42, 45, 40, 40, 45, 50, 29, 40, 41, 42, 45, 40, 40, 45, 50, 29, 40, 41, 42]

# %%
z,p=ztest(data, value=35)

# %%
print(z,p)
# Out:
# 8.578371730023221 9.62255415335246e-18
